# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt

# %%
# Se importan los CSV de las 10 colonias
df_ubereats_centro = pd.read_csv(r'csv/ubereats-pizza-centro.csv')
df_ubereats_alamos = pd.read_csv(r'csv/ubereats-pizza-alamos.csv')
df_ubereats_juriquilla = pd.read_csv(r'csv/ubereats-pizza-juriquilla.csv')
df_ubereats_milenio = pd.read_csv(r'csv/ubereats-pizza-milenio.csv')
df_ubereats_refugio = pd.read_csv(r'csv/ubereats-pizza-refugio.csv')
df_ubereats_balvanera = pd.read_csv(r'csv/ubereats-pizza-balvanera.csv')
df_ubereats_campanario = pd.read_csv(r'csv/ubereats-pizza-campanario.csv')
df_ubereats_cerritocolorado = pd.read_csv(r'csv/ubereats-pizza-cerritocolorado.csv')
df_ubereats_cimatario = pd.read_csv(r'csv/ubereats-pizza-cimatario.csv')
df_ubereats_el_pueblito = pd.read_csv(r'csv/ubereats-pizza-el-pueblito.csv')

df_rappi_centro = pd.read_csv(r'csv/rappi-pizza-centro.csv')
df_rappi_alamos = pd.read_csv(r'csv/rappi-pizza-alamos.csv')
df_rappi_juriquilla = pd.read_csv(r'csv/rappi-pizza-juriquilla.csv')
df_rappi_milenio = pd.read_csv(r'csv/rappi-pizza-milenio.csv')
df_rappi_refugio = pd.read_csv(r'csv/rappi-pizza-refugio.csv')
df_rappi_balvanera = pd.read_csv(r'csv/rappi-pizza-balvanera.csv')
df_rappi_campanario = pd.read_csv(r'csv/rappi-pizza-campanario.csv')
df_rappi_cerritocolorado = pd.read_csv(r'csv/rappi-pizza-cerritocolorado.csv')
df_rappi_cimatario = pd.read_csv(r'csv/rappi-pizza-cimatario.csv')
df_rappi_el_pueblito = pd.read_csv(r'csv/rappi-pizza-el-pueblito.csv')

centro = [df_ubereats_centro,df_rappi_centro]
alamos = [df_ubereats_alamos,df_rappi_alamos]
juriquilla = [df_ubereats_juriquilla,df_rappi_juriquilla]
milenio = [df_ubereats_milenio,df_rappi_milenio] 
refugio = [df_ubereats_refugio,df_rappi_refugio]
balvanera = [df_ubereats_balvanera,df_rappi_balvanera]
campanario = [df_ubereats_campanario,df_rappi_campanario]
cerritoC = [df_ubereats_cerritocolorado,df_rappi_cerritocolorado]
cimatario = [df_ubereats_cimatario,df_rappi_cimatario]
pueblito = [df_ubereats_el_pueblito,df_rappi_el_pueblito]

df_centro = pd.concat(centro, ignore_index=True)
df_alamos = pd.concat(alamos, ignore_index=True)
df_juriquilla = pd.concat(juriquilla, ignore_index=True)
df_milenio = pd.concat(milenio, ignore_index=True)
df_refugio = pd.concat(refugio, ignore_index=True)
df_balvanera = pd.concat(balvanera, ignore_index=True)
df_campanario = pd.concat(campanario, ignore_index=True)
df_cerritoC = pd.concat(cerritoC, ignore_index=True)
df_cimatario = pd.concat(cimatario, ignore_index=True)
df_pueblito = pd.concat(pueblito, ignore_index=True)

# %%
#Se limpia el precio para remover el MX$
df_centro['price-food'] = df_centro['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_alamos['price-food'] = df_alamos['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_juriquilla['price-food'] = df_juriquilla['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_milenio['price-food'] = df_milenio['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_refugio['price-food'] = df_refugio['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_balvanera['price-food'] = df_balvanera['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_campanario['price-food'] = df_campanario['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_cerritoC['price-food'] = df_cerritoC['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_cimatario['price-food'] = df_cimatario['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_pueblito['price-food'] = df_pueblito['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)

# %%
#Se Obtienen unicamnte los productos que incluyen la palabra pizza y los nombres de los productos se convierten a minusculas
df_centroP = df_centro[df_centro['name-food'].str.contains("pizza", na=False, case=False)]
df_centroP = df_centroP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_centroP.reset_index(drop=True, inplace=True)

df_alamosP = df_alamos[df_alamos['name-food'].str.contains("pizza", na=False, case=False)]
df_alamosP = df_alamosP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_alamosP.reset_index(drop=True, inplace=True)

df_juriquillaP = df_juriquilla[df_juriquilla['name-food'].str.contains("pizza", na=False, case=False)]
df_juriquillaP = df_juriquillaP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_juriquillaP.reset_index(drop=True, inplace=True)

df_milenioP = df_milenio[df_milenio['name-food'].str.contains("pizza", na=False, case=False)]
df_milenioP = df_milenioP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_milenioP.reset_index(drop=True, inplace=True)

df_refugioP = df_refugio[df_refugio['name-food'].str.contains("pizza", na=False, case=False)]
df_refugioP = df_refugioP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_refugioP.reset_index(drop=True, inplace=True)

df_balvaneraP = df_balvanera[df_balvanera['name-food'].str.contains("pizza", na=False, case=False)]
df_balvaneraP = df_balvaneraP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_balvaneraP.reset_index(drop=True, inplace=True)

df_campanarioP = df_campanario[df_campanario['name-food'].str.contains("pizza", na=False, case=False)]
df_campanarioP = df_campanarioP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_campanarioP.reset_index(drop=True, inplace=True)

df_cerritoCP = df_cerritoC[df_cerritoC['name-food'].str.contains("pizza", na=False, case=False)]
df_cerritoCP = df_cerritoCP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_cerritoCP.reset_index(drop=True, inplace=True)

df_cimatarioP = df_cimatario[df_cimatario['name-food'].str.contains("pizza", na=False, case=False)]
df_cimatarioP = df_cimatarioP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_cimatarioP.reset_index(drop=True, inplace=True)

df_pueblitoP = df_pueblito[df_pueblito['name-food'].str.contains("pizza", na=False, case=False)]
df_pueblitoP = df_pueblitoP.apply(lambda x: x.str.lower() if(x.dtype == "object") else x)
df_pueblitoP.reset_index(drop=True, inplace=True)

# %%
#Numero de Pizzerias Por Colonia
colonias = ['Centro','Alamos','Juriquilla','Milenio 3','El Refugio','Balvanera','El Campanario','Cerrito Colorado','Cimatario','El Pueblito']

NRCentro = df_centroP.loc[:,['name']]
NRCentro = NRCentro.drop_duplicates()
NResCentro = NRCentro['name'].count()
print('Pizzerias en Centro:') 
print(NResCentro)

NRAlamos = df_alamosP.loc[:,['name']]
NRAlamos = NRAlamos.drop_duplicates()
NResAlamos = NRAlamos['name'].count()
print('Pizzerias en Alamos:') 
print(NResAlamos)

NRJuriquilla = df_juriquillaP.loc[:,['name']]
NRJuriquilla = NRJuriquilla.drop_duplicates()
NResJuriquilla = NRJuriquilla['name'].count()
print('Pizzerias en Juriquilla:') 
print(NResJuriquilla)

NRMilenio = df_milenioP.loc[:,['name']]
NRMilenio = NRMilenio.drop_duplicates()
NResMilenio = NRMilenio['name'].count()
print('Pizzerias en Milenio 3:') 
print(NResMilenio)

NRRefugio = df_refugioP.loc[:,['name']]
NRRefugio = NRRefugio.drop_duplicates()
NResRefugio = NRRefugio['name'].count()
print('Pizzerias en El Refugio:') 
print(NResRefugio)

NRBalvanera = df_balvaneraP.loc[:,['name']]
NRBalvanera = NRBalvanera.drop_duplicates()
NResBalvanera = NRBalvanera['name'].count()
print('Pizzerias en Balvanera:') 
print(NResBalvanera)

NRCampanario = df_campanarioP.loc[:,['name']]
NRCampanario = NRCampanario.drop_duplicates()
NResCampanario = NRCampanario['name'].count()
print('Pizzerias en El Campanario:') 
print(NResCampanario)

NRCerritoC = df_cerritoCP.loc[:,['name']]
NRCerritoC = NRCerritoC.drop_duplicates()
NResCerritoC = NRCerritoC['name'].count()
print('Pizzerias en Cerrito Colorado:') 
print(NResCerritoC)

NRCimatario = df_cimatarioP.loc[:,['name']]
NRCimatario = NRCimatario.drop_duplicates()
NResCimatario = NRCimatario['name'].count()
print('Pizzerias en Cimatario:') 
print(NResCimatario)

NRPueblito = df_pueblitoP.loc[:,['name']]
NRPueblito = NRPueblito.drop_duplicates()
NResPueblito = NRPueblito['name'].count()
print('Pizzerias en El Pueblito:') 
print(NResPueblito)
# Out:
# Pizzerias en Centro:
# 102
# Pizzerias en Alamos:
# 80
# Pizzerias en Juriquilla:
# 55
# Pizzerias en Milenio 3:
# 92
# Pizzerias en El Refugio:
# 23
# Pizzerias en Balvanera:
# 20
# Pizzerias en El Campanario:
# 53
# Pizzerias en Cerrito Colorado:
# 53
# Pizzerias en Cimatario:
# 98
# Pizzerias en El Pueblito:
# 44

# %%
plt.figure(figsize = (15, 5))
plt.bar(colonias,[NResCentro,NResAlamos,NResJuriquilla,NResMilenio,NResRefugio,NResBalvanera,NResCampanario,NResCerritoC,NResCimatario,NResPueblito])
plt.title('Numero de Restaurantes por Colonia')
plt.show()

# %%
#Se Obtienen los Promedios de los precios por colonia
PromCentro = df_centroP['price-food'].mean()
print('Centro')
print(PromCentro)
PromAlamos = df_alamosP['price-food'].mean()
print('Alamos')
print(PromAlamos)
PromJuriquilla = df_juriquillaP['price-food'].mean()
print('Juruquilla')
print(PromJuriquilla)
PromMilenio = df_milenioP['price-food'].mean()
print('Milenio')
print(PromMilenio)
PromRefugio = df_refugioP['price-food'].mean()
print('Refugio')
print(PromRefugio)
PromBalvanera = df_balvaneraP['price-food'].mean()
print('Balvanera')
print(PromBalvanera)
PromCampanario = df_campanarioP['price-food'].mean()
print('Campanario')
print(PromCampanario)
PromCerrito = df_cerritoCP['price-food'].mean()
print('CerritoC')
print(PromCerrito)
PromCimatario = df_cimatarioP['price-food'].mean()
print('Cimatario')
print(PromCimatario)
PromPueblito = df_pueblitoP['price-food'].mean()
print('Pueblito')
print(PromPueblito)
# Out:
# Centro
# 181.59377997179126
# Alamos
# 176.3359879032258
# Juruquilla
# 176.07762938230383
# Milenio
# 178.9778624535316
# Refugio
# 192.55559210526317
# Balvanera
# 172.1778947368421
# Campanario
# 183.73896321070234
# CerritoC
# 148.33047895500727
# Cimatario
# 179.02812407680946
# Pueblito
# 163.49787234042554

# %%
#Se Obtienen el Precio Modal por Colonia
ModeCentro = df_centroP['price-food'].mode()[0]
print('Centro')
print(ModeCentro)
ModeAlamos = df_alamosP['price-food'].mode()[0]
print('Alamos')
print(ModeAlamos)
ModeJuriquilla = df_juriquillaP['price-food'].mode()[0]
print('Juruquilla')
print(ModeJuriquilla)
ModeMilenio = df_milenioP['price-food'].mode()[0]
print('Milenio')
print(ModeMilenio)
ModeRefugio = df_refugioP['price-food'].mode()[0]
print('Refugio')
print(ModeRefugio)
ModeBalvanera = df_balvaneraP['price-food'].mode()[0]
print('Balvanera')
print(ModeBalvanera)
ModeCampanario = df_campanarioP['price-food'].mode()[0]
print('Campanario')
print(ModeCampanario)
ModeCerrito = df_cerritoCP['price-food'].mode()[0]
print('CerritoC')
print(ModeCerrito)
ModeCimatario = df_cimatarioP['price-food'].mode()[0]
print('Cimatario')
print(ModeCimatario)
ModePueblito = df_pueblitoP['price-food'].mode()[0]
print('Pueblito')
print(ModePueblito)
# Out:
# Centro
# 189.0
# Alamos
# 160.0
# Juruquilla
# 140.0
# Milenio
# 179.0
# Refugio
# 199.0
# Balvanera
# 145.0
# Campanario
# 175.0
# CerritoC
# 119.0
# Cimatario
# 189.0
# Pueblito
# 150.0

# %%
plt.figure(figsize = (11, 8))
plt.subplot(2,1,1)
plt.barh(colonias,[PromCentro,PromAlamos,PromJuriquilla,PromMilenio,PromRefugio,PromBalvanera,PromCampanario,PromCerrito,PromCimatario,PromPueblito])
plt.xlabel('Precio')
plt.title('Precio Promedio de Pizzas por Colonia')
plt.subplot(2,1,2)
plt.barh(colonias,[ModeCentro,ModeAlamos,ModeJuriquilla,ModeMilenio,ModeRefugio,ModeBalvanera,ModeCampanario,ModeCerrito,ModeCimatario,ModePueblito])
plt.xlabel('Precio')
plt.title('Precio Modal de Pizzas por Colonia')
plt.show()

# %%
#Se Obtienen los Promedios de los ratings
PromRCentro = df_centroP['rating'].mean()
print('Centro')
print(PromRCentro)
PromRAlamos = df_alamosP['rating'].mean()
print('Alamos')
print(PromRAlamos)
PromRJuriquilla = df_juriquillaP['rating'].mean()
print('Juruquilla')
print(PromRJuriquilla)
PromRMilenio = df_milenioP['rating'].mean()
print('Milenio')
print(PromRMilenio)
PromRRefugio = df_refugioP['rating'].mean()
print('Refugio')
print(PromRRefugio)
PromRBalvanera = df_balvaneraP['rating'].mean()
print('Balvanera')
print(PromRBalvanera)
PromRCampanario = df_campanarioP['rating'].mean()
print('Campanario')
print(PromRCampanario)
PromRCerrito = df_cerritoCP['rating'].mean()
print('CerritoC')
print(PromRCerrito)
PromRCimatario = df_cimatarioP['rating'].mean()
print('Cimatario')
print(PromRCimatario)
PromRPueblito = df_pueblitoP['rating'].mean()
print('Pueblito')
print(PromRPueblito)
# Out:
# Centro
# 4.540628637951105
# Alamos
# 4.6
# Juruquilla
# 4.563341645885287
# Milenio
# 4.442338709677419
# Refugio
# 4.5410714285714295
# Balvanera
# 4.591869918699187
# Campanario
# 4.473937677053824
# CerritoC
# 4.600000000000001
# Cimatario
# 4.529764705882354
# Pueblito
# 4.64873417721519

# %%
plt.barh(colonias,[PromRCentro,PromRAlamos,PromRJuriquilla,PromRMilenio,PromRRefugio,PromRBalvanera,PromRCampanario,PromRCerrito,PromRCimatario,PromRPueblito])
plt.xlabel('Precio')
plt.title('Rating Promedio de Pizzerias por Colonia')
plt.show()

# %%
#Varianza de precios por Colonia
print('Varianza Precios Centro')
numpy.std(df_centroP['price-food'])
# Out:
# Varianza Precios Centro
# 61.208145995492025

# %%
print('Varianza Precios Alamos')
numpy.std(df_alamosP['price-food'])
# Out:
# Varianza Precios Alamos
# 61.7794342903995

# %%
print('Varianza Precios Juriquilla')
numpy.std(df_juriquillaP['price-food'])
# Out:
# Varianza Precios Juriquilla
# 72.91317864251837

# %%
print('Varianza Precios Milenio 3')
numpy.std(df_milenioP['price-food'])
# Out:
# Varianza Precios Milenio 3
# 59.50510626525318

# %%
print('Varianza Precios El Refugio')
numpy.std(df_refugioP['price-food'])
# Out:
# Varianza Precios El Refugio
# 58.73472843209132

# %%
print('Varianza Precios Balvanera')
numpy.std(df_balvaneraP['price-food'])
# Out:
# Varianza Precios Balvanera
# 54.289882122095506

# %%
print('Varianza Precios El Campanario')
numpy.std(df_campanarioP['price-food'])
# Out:
# Varianza Precios El Campanario
# 64.95478311688207

# %%
print('Varianza Precios Cerrito Colorado')
numpy.std(df_cerritoCP['price-food'])
# Out:
# Varianza Precios Cerrito Colorado
# 56.693513539199245

# %%
print('Varianza Precios Cimatario')
numpy.std(df_cimatarioP['price-food'])
# Out:
# Varianza Precios Cimatario
# 62.146405742427916

# %%
print('Varianza Precios El Pueblito')
numpy.std(df_pueblitoP['price-food'])
# Out:
# Varianza Precios El Pueblito
# 50.05422516097889

# %%
#Dispercion de Precios y Rating en el Centro
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_centroP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza Centro')
plt.subplot(2,1,2)
plt.plot(df_centroP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias Centro')
plt.show()

# %%
#Dispercion de Precios y Rating en Alamos
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_alamosP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - Alamos')
plt.subplot(2,1,2)
plt.plot(df_alamosP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - Alamos')
plt.show()

# %%
#Dispercion de Precios y Rating en Juriquilla
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_juriquillaP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - Juriquilla')
plt.subplot(2,1,2)
plt.plot(df_juriquillaP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - Juriquilla')
plt.show()

# %%
#Dispercion de Precios y Rating en Milenio 3
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_milenioP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - Milenio 3')
plt.subplot(2,1,2)
plt.plot(df_milenioP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - Milenio 3')
plt.show()

# %%
#Dispercion de Precios y Rating en El Refugio
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_refugioP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - El Refugio')
plt.subplot(2,1,2)
plt.plot(df_refugioP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - El Refugio')
plt.show()

# %%
#Dispercion de Precios y Rating en Balvanera
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_balvaneraP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - Balvanera')
plt.subplot(2,1,2)
plt.plot(df_balvaneraP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - Balvanera')
plt.show()

# %%
#Dispercion de Precios y Rating en El Campanario
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_campanarioP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - El Campanario')
plt.subplot(2,1,2)
plt.plot(df_campanarioP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - El Campanario')
plt.show()

# %%
#Dispercion de Precios y Rating en Cerrito Colorado
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_cerritoCP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - Cerrito Colorado')
plt.subplot(2,1,2)
plt.plot(df_cerritoCP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - Cerrito Colorado')
plt.show()

# %%
#Dispercion de Precios y Rating en Cimatario
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_cimatarioP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - Cimatario')
plt.subplot(2,1,2)
plt.plot(df_cimatarioP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - Cimatario')
plt.show()

# %%
#Dispercion de Precios y Rating en El Pueblito
plt.figure(figsize = (10, 6))
plt.subplot(2,1,1)
plt.plot(df_pueblitoP['price-food'],'ro',ms=1)
plt.ylabel('Precio')
plt.xlabel('ID')
plt.title('Precios de Pizza - El Pueblito')
plt.subplot(2,1,2)
plt.plot(df_pueblitoP['rating'],'bo',ms=1)
plt.ylabel('Rating')
plt.xlabel('ID')
plt.title('Rating de Pizzerias - El Pueblito')
plt.show()

# %%
#Menu Tipico en el Centro
MenuCentro = df_centroP.groupby('name-food').name.nunique().reset_index()
print(MenuCentro.loc[MenuCentro['name'] > 10])
pizzacen = ['Carnes Frias','Pepperoni','Hawaiana','Italiana','Margherita','Mexicana','Vegetariana']
comuncen = [12,46,45,12,36,30,35]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en el Centro')
plt.show()
# Out:
#               name-food  name
# 139  pizza carnes frías    12
# 260  pizza de pepperoni    16
# 433      pizza hawaiana    45
# 449      pizza italiana    12
# 476     pizza margarita    23
# 477    pizza margherita    13
# 521      pizza mexicana    30
# 562     pizza pepperoni    30
# 694   pizza vegetariana    35

# %%
#Menu Tipico en Alamos
MenuAlamos = df_alamosP.groupby('name-food').name.nunique().reset_index()
print(MenuAlamos.loc[MenuAlamos['name'] > 8])
pizzacen = ['Carnes Frias','Pepperoni','Hawaiana','Italiana','Margherita','Mexicana','Ranchera','Vegetariana']
comuncen = [20,30,37,9,16,25,9,26]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en Alamos')
plt.show()
# Out:
#                  name-food  name
# 100     pizza carnes frías    11
# 167  pizza de carnes frías     9
# 191     pizza de pepperoni    12
# 322         pizza hawaiana    37
# 338         pizza italiana     9
# 357        pizza margarita    16
# 382         pizza mexicana    25
# 408        pizza pepperoni    18
# 441         pizza ranchera     9
# 493      pizza vegetariana    26

# %%
#Menu Tipico en Juriquilla
MenuJuriquilla = df_juriquillaP.groupby('name-food').name.nunique().reset_index()
print(MenuJuriquilla.loc[MenuJuriquilla['name'] > 5])
pizzacen = ['4 Quesos','Pepperoni','Hawaiana','Margherita','Mexicana','Vegetariana']
comuncen = [6,18,16,12,9,12]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en Juriquilla')
plt.show()
# Out:
#                name-food  name
# 86   pizza cuatro quesos     6
# 127   pizza de pepperoni     7
# 216       pizza hawaiana    16
# 241      pizza margarita    12
# 256       pizza mexicana     9
# 288      pizza pepperoni    11
# 354    pizza vegetariana    12

# %%
#Menu Tipico en Milenio 3
MenuMilenio = df_milenioP.groupby('name-food').name.nunique().reset_index()
print(MenuMilenio.loc[MenuMilenio['name'] > 9])
pizzacen = ['Carnes Frias','Pepperoni','Hawaiana','Italiana','Margherita','Mexicana','Pastor','Vegetariana']
comuncen = [11,39,35,13,17,26,10,29]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en Milenio 3')
plt.show()
# Out:
#               name-food  name
# 94   pizza carnes frías    11
# 188  pizza de pepperoni    16
# 311      pizza hawaiana    35
# 324      pizza italiana    13
# 345     pizza margarita    17
# 375      pizza mexicana    26
# 404        pizza pastor    10
# 412     pizza pepperoni    23
# 528   pizza vegetariana    29

# %%
#Menu Tipico en El Refugio
Menurefugio = df_refugioP.groupby('name-food').name.nunique().reset_index()
print(Menurefugio.loc[Menurefugio['name'] > 2])
pizzacen = ['4 Quesos','Carnes Frias','Carne','Pepperoni','Hawaiana','Jamon','Margherita','Mexicana','Napolitana','Vegetariana']
comuncen = [5,6,3,13,9,3,9,4,3,4]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en El Refugio')
plt.show()
# Out:
#                     name-food  name
# 11             pizza 4 quesos     5
# 33         pizza carnes frías     3
# 58             pizza de carne     3
# 60      pizza de carnes frías     3
# 77         pizza de pepperoni     5
# 111            pizza hawaiana     9
# 125       pizza jamón mediana     3
# 128           pizza margarita     7
# 132          pizza margherita     3
# 139            pizza mexicana     4
# 150  pizza napolitana mediana     3
# 162           pizza pepperoni     8
# 202         pizza vegetariana     4

# %%
#Menu Tipico en Balvanera
MenuBalvanera = df_balvaneraP.groupby('name-food').name.nunique().reset_index()
print(MenuBalvanera.loc[MenuBalvanera['name'] > 2])
pizzacen = ['4 Quesos','Dulce','Hawaiana','Margherita','Mexicana']
comuncen = [3,3,4,4,3]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en Balvanera')
plt.show()
# Out:
#           name-food  name
# 14   pizza 4 quesos     3
# 47      pizza dulce     3
# 69   pizza hawaiana     4
# 80  pizza margarita     4
# 86   pizza mexicana     3

# %%
#Menu Tipico en El Campanario
MenuCampanario = df_campanarioP.groupby('name-food').name.nunique().reset_index()
print(MenuCampanario.loc[MenuCampanario['name'] > 5])
pizzacen = ['Pepperoni','Hawaiana','Margherita','Mexicana','Vegetariana']
comuncen = [22,20,15,14,12]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en El Campanario')
plt.show()
# Out:
#               name-food  name
# 126  pizza de pepperoni    12
# 209      pizza hawaiana    20
# 228     pizza margarita     6
# 229    pizza margherita     9
# 250      pizza mexicana    14
# 269     pizza pepperoni    10
# 333   pizza vegetariana    12

# %%
#Menu Tipico en Cerrito Colorado
MenuCerrito = df_cerritoCP.groupby('name-food').name.nunique().reset_index()
print(MenuCerrito.loc[MenuCerrito['name'] > 4])
pizzacen = ['Pepperoni','Queso','Hawaiana','Margherita','Mexicana','Vegetariana']
comuncen = [10,5,15,5,11,12]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en Cerrito Colorado')
plt.show()
# Out:
#               name-food  name
# 150  pizza de pepperoni     5
# 157      pizza de queso     5
# 229      pizza hawaiana    15
# 266     pizza margarita     5
# 291      pizza mexicana    11
# 309     pizza pepperoni     5
# 380   pizza vegetariana    12

# %%
#Menu Tipico en Cimatario
MenuCimatario = df_cimatarioP.groupby('name-food').name.nunique().reset_index()
print(MenuCimatario.loc[MenuCimatario['name'] > 9])
pizzacen = ['Carnes Frias','Pepperoni','Hawaiana','Margherita','Mexicana','Vegetariana']
comuncen = [12,41,46,35,27,36]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en Cimatario')
plt.show()
# Out:
#               name-food  name
# 136  pizza carnes frías    12
# 260  pizza de pepperoni    16
# 423      pizza hawaiana    46
# 468     pizza margarita    22
# 469    pizza margherita    13
# 511      pizza mexicana    27
# 547     pizza pepperoni    25
# 669   pizza vegetariana    36

# %%
#Menu Tipico en El Pueblito
MenuPueblito = df_pueblitoP.groupby('name-food').name.nunique().reset_index()
print(MenuPueblito.loc[MenuPueblito['name'] > 3])
pizzacen = ['Carnes Frias','Camaron','Pepperoni','Hawaiana','Margherita','Mexicana','Vegetariana']
comuncen = [4,4,13,18,7,12,11]
plt.pie(comuncen, labels=pizzacen)
plt.title('Menu Tipico de Pizzerias en El Pueblito')
plt.show()
# Out:
#                  name-food  name
# 77      pizza carnes frías     4
# 126       pizza de camarón     4
# 146     pizza de pepperoni     5
# 199         pizza hawaiana    14
# 205  pizza hawaiana grande     4
# 226        pizza margarita     7
# 240         pizza mexicana    12
# 270        pizza pepperoni     8
# 331      pizza vegetariana    11
